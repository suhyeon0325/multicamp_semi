# %%
import folium
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import box
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from shapely.geometry import Point
from pyproj import Proj, transform, CRS

# %%
import matplotlib.font_manager as fm

# 한국어 출력을 위한 폰트 설정
plt.rc('font', family='NanumGothic') 

# 마이너스 기호가 깨지는 것을 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
data = gpd.read_file("data/서울시 비상소화장치 위치정보.csv")

# %%
data
# Out:
#         연번 비상소화장치일련번호 일련번호              X좌표              Y좌표 비상소화장치고유번호  \
# 0        1  110080030  451  192436.05620538  552336.95498254         41
# 1        2  110080031  452  191972.54288665  554384.19107578         54
# 2        3  110080032  453  195705.68084358  555164.49557405         56
# 3        4  110080033  454  195646.35573731  555661.51678319         57
# 4        5  110080034  455  191543.20535296  555165.58938338         55
# ...    ...        ...  ...              ...              ...        ...
# 2690  2691  110086927    0  195867.26344686  550812.72472093     000118
# 2691  2692  110086928    0  195978.50137131  550812.36698320     000119
# 2692  2693  110086929    0  196051.06076163  550814.24186619     000120
# 2693  2694  110086930    0  196029.38712340  550750.44879355     000121
# 2694  2695  110086931    0  196050.26877634  550667.20011006     000122
#
#        사용구분 삭제여부          업데이트날짜 geometry
# 0     52201    N  20231116120041     None
# 1     52202    N  20231017120007     None
# 2     52201    N  20231111120009     None
# 3     52201    N  20231111120009     None
# 4     52201    N  20231024120006     None
# ...     ...  ...             ...      ...
# 2690  52201    N  20231115120002     None
# 2691  52201    N  20231109120021     None
# 2692  52201    N  20231109120021     None
# 2693  52201    N  20231109120021     None
# 2694  52201    N  20231109120021     None
#
# [2695 rows x 10 columns]

# %%
# 좌표계 정의
# 한국 중부원점(Korea 2000 Central Belt) EPSG:5186
proj_korea = Proj(init='epsg:5186')
# WGS84
proj_wgs84 = Proj(init='epsg:4326')
# Out:
# C:\Users\1qlqj\Desktop\multicamp_semi\multicamp_semi\venv\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\1qlqj\Desktop\multicamp_semi\multicamp_semi\venv\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
# X좌표와 Y좌표를 위도와 경도로 변환하는 함수
def convert_coords(x, y):
    lon, lat = transform(proj_korea, proj_wgs84, x, y)
    return lat, lon

# %%
# 모든 좌표 변환
data[['위도', '경도']] = data.apply(lambda row: convert_coords(row['X좌표'], row['Y좌표']), axis=1, result_type="expand")
# Out:
# C:\Users\1qlqj\AppData\Local\Temp\ipykernel_16876\3974450290.py:3: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(proj_korea, proj_wgs84, x, y)

# %%
data
# Out:
#         연번 비상소화장치일련번호 일련번호              X좌표              Y좌표 비상소화장치고유번호  \
# 0        1  110080030  451  192436.05620538  552336.95498254         41
# 1        2  110080031  452  191972.54288665  554384.19107578         54
# 2        3  110080032  453  195705.68084358  555164.49557405         56
# 3        4  110080033  454  195646.35573731  555661.51678319         57
# 4        5  110080034  455  191543.20535296  555165.58938338         55
# ...    ...        ...  ...              ...              ...        ...
# 2690  2691  110086927    0  195867.26344686  550812.72472093     000118
# 2691  2692  110086928    0  195978.50137131  550812.36698320     000119
# 2692  2693  110086929    0  196051.06076163  550814.24186619     000120
# 2693  2694  110086930    0  196029.38712340  550750.44879355     000121
# 2694  2695  110086931    0  196050.26877634  550667.20011006     000122
#
#        사용구분 삭제여부          업데이트날짜 geometry         위도          경도
# 0     52201    N  20231116120041     None  37.570543  126.914379
# 1     52202    N  20231017120007     None  37.588984  126.909110
# 2     52201    N  20231111120009     None  37.596040  126.951373
# 3     52201    N  20231111120009     None  37.600518  126.950699
# 4     52201    N  20231024120006     None  37.596021  126.904240
# ...     ...  ...             ...      ...        ...         ...
# 2690  52201    N  20231115120002     None  37.556831  126.953228
# 2691  52201    N  20231109120021     None  37.556829  126.954487
# 2692  52201    N  20231109120021     None  37.556846  126.955308
# 2693  52201    N  20231109120021     None  37.556271  126.955063
# 2694  52201    N  20231109120021     None  37.555521  126.955300
#
# [2695 rows x 12 columns]

# %%
# Point 객체로 변환
geometry = [Point(xy) for xy in zip(data["경도"], data["위도"])]

# %%
# GeoDataFrame 생성
gdf = gpd.GeoDataFrame(data, geometry=geometry)

# %%
gdf = gdf.drop(columns = ['일련번호', 'X좌표', 'Y좌표', '사용구분', '삭제여부'])

# %%
gdf = gdf.drop(columns = ['업데이트날짜', '위도', '경도'])

# %%
gdf.head()
# Out:
#   연번 비상소화장치일련번호 비상소화장치고유번호                    geometry
# 0  1  110080030         41  POINT (126.91438 37.57054)
# 1  2  110080031         54  POINT (126.90911 37.58898)
# 2  3  110080032         56  POINT (126.95137 37.59604)
# 3  4  110080033         57  POINT (126.95070 37.60052)
# 4  5  110080034         55  POINT (126.90424 37.59602)

# %%
gdf.to_csv('서울시_비상소화장치_좌표.csv', index=False)

# %%
import folium
from folium.plugins import MarkerCluster
import geopandas as gpd

# 예제 데이터를 GeoDataFrame으로 로딩
# gdf = 여기에는 실제 데이터를 로딩하는 코드가 들어가야 합니다.

# 서울시 중심에 지도를 생성
m = folium.Map(location=[37.5665, 126.9780], zoom_start=11)

# 클러스터 객체 생성
marker_cluster = MarkerCluster().add_to(m)

# GeoDataFrame 내의 각 지점에 대해 마커 추가
for idx, row in gdf.iterrows():
    folium.Marker(location=[row['geometry'].y, row['geometry'].x]).add_to(marker_cluster)

# 지도 표시
#m.save('seoul_fire_extinguishers.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2378f0789a35ca7e364b8ecca80922cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2378f0789a35ca7e364b8ecca80922cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2378f0789a35ca7e364b8ecca80922cf = L.map(
#                 &quot;map_2378f0789a35ca7e364b8ecca80922cf&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_858f208dc2260e5930498d2735a2fbbb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_858f208dc2260e5930498d2735a2fbbb.addTo(map_2378f0789a35ca7e364b8ecca80922cf);
#
#
#             var marker_cluster_91f61a012a686f278a6612a45a98e7e9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_097a2dac82ff74492259c50182db98cd = L.marker(
#                 [37.570542820324434, 126.9143790416038],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_89cce81d99ffab9905d224cf3e9dc1fa = L.marker(
#                 [37.588984348035225, 126.90910983392715],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_068477bbc59154d0e11ea2a175e37593 = L.marker(
#                 [37.596039805648054, 126.95137336075969],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_449119683ca97529ebb855d235b85a0b = L.marker(
#                 [37.600517642130285, 126.9506986396432],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_fd89ebea1ee8155ef7c7077d9e2d64bb = L.marker(
#                 [37.5960208309644, 126.90423968355844],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_4e1d5f644f4ab1fce6e723d6ad2c5c61 = L.marker(
#                 [37.626076505043514, 126.91163022715911],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_5ca19ebb7cb055c34f8b6cd4046e66ac = L.marker(
#                 [37.62485911125063, 126.92347558169996],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_24574a1181606914734faac631667b43 = L.marker(
#                 [37.55828521981003, 126.9327473604666],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_c5cb5644d9742ad4422c133d9582d654 = L.marker(
#                 [37.56025013975677, 126.9303466027321],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_9c764658ae5efd69fcbd4e30fc682ce7 = L.marker(
#                 [37.58589475500564, 126.90628457366566],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_0757be07b6d58e901129ec0d3b6104c4 = L.marker(
#                 [37.50978891942538, 126.95803377496611],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_b1fc790c36614caa5b83c4ecac58d38c = L.marker(
#                 [37.50418966227235, 126.96903122385858],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_43c3733bf3b650ac690b660da8acce27 = L.marker(
#                 [37.50451929782551, 126.96756676597144],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_bccae773aeaa7c1f34c4b59f5b62ea8a = L.marker(
#                 [37.50832871300055, 126.93600460713391],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_985a2579a44e268f46a5308fee96ca10 = L.marker(
#                 [37.50477306367343, 126.97122682452898],
#                 {}
#             ).addTo(marker_cluster_91f61a012a686f278a6612a45a98e7e9);
#
#
#             var marker_6aca8ee8aebd3a9a858aadfb9fb0f4ea = L.marker(
#                 [37.48713019291381, 126.91625842096838],
#                 {}
