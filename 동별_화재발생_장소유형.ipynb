# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import geopandas as gpd
from shapely.geometry import box

# %%
import matplotlib.font_manager as fm

# 한국어 출력을 위한 폰트 설정
plt.rc('font', family='NanumGothic') 

# 마이너스 기호가 깨지는 것을 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df_2021 = pd.read_csv("data/화재발생_동별_2021.csv", encoding='cp949')
df_2022 = pd.read_csv("data/화재발생_동별_2022.csv", encoding='cp949')

# %%
df_2021
# Out:
#      자치구     동 단독주택 공동주택 기타주택 학교 일반업무 판매시설 숙박시설 종교시설 의료시설 공장 및 창고 작업장 위락오락시설  \
# 0    종로구   사직동    -    1    -  1    1    1    -    -    -       -   -      -
# 1    종로구   삼청동    1    -    -  -    1    1    -    -    -       -   -      -
# 2    종로구   부암동    -    2    -  1    -    -    -    -    -       -   -      -
# 3    종로구   평창동    4    2    -  -    -    1    -    1    -       -   -      -
# 4    종로구   무악동    -    2    -  -    -    -    -    -    -       -   -      -
# ..   ...   ...  ...  ...  ... ..  ...  ...  ...  ...  ...     ...  ..    ...
# 419  강동구  천호2동    4    7    -  -    1    1    5    -    1       -   -      1
# 420  강동구    길동    7    4    -  1    3    2    -    -    2       1   1      2
# 421  강동구   강일동    -    2    -  -    2    -    -    -    -       -   -      -
# 422  강동구  상일1동    1    1    -  -    -    1    -    -    -       -   1      -
# 423  강동구  상일2동    -    -    -  -    -    -    -    -    1       -   -      -
#
#     음식점 일상서비스시설 기타
# 0     3       -  1
# 1     1       -  1
# 2     -       -  -
# 3     -       -  3
# 4     -       -  -
# ..   ..     ... ..
# 419   1       -  1
# 420   -       1  2
# 421   -       -  1
# 422   -       -  1
# 423   -       -  -
#
# [424 rows x 17 columns]

# %%
df_2022
# Out:
#      자치구     동 단독주택 공동주택 기타주택 학교 일반업무 판매시설 숙박시설 종교시설 의료시설 공장 및 창고 작업장 위락오락시설  \
# 0    종로구   사직동    1    -    -  -    -    1    -    -    -       -   -      -
# 1    종로구   삼청동    -    -    -  -    -    -    -    -    -       -   -      -
# 2    종로구   부암동    1    1    -  -    -    -    -    -    -       -   -      -
# 3    종로구   평창동    4    1    -  -    -    -    -    -    -       -   -      -
# 4    종로구   무악동    -    4    -  -    -    -    -    -    -       -   -      -
# ..   ...   ...  ...  ...  ... ..  ...  ...  ...  ...  ...     ...  ..    ...
# 421  강동구  천호2동    2    6    -  -    -    1    1    -    -       -   1      -
# 422  강동구    길동    1    3    -  -    5    -    -    -    -       -   -      1
# 423  강동구   강일동    -    3    -  -    1    -    -    -    -       -   -      -
# 424  강동구  상일1동    -    4    -  -    -    -    -    -    -       1   -      -
# 425  강동구  상일2동    -    3    -  -    -    -    -    -    -       -   -      -
#
#     음식점 일상서비스시설 기타
# 0     3       -  3
# 1     3       -  1
# 2     -       -  1
# 3     -       -  -
# 4     -       -  -
# ..   ..     ... ..
# 421   2       -  -
# 422   3       2  1
# 423   1       -  -
# 424   -       -  -
# 425   -       -  -
#
# [426 rows x 17 columns]
