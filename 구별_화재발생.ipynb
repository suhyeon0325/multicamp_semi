# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import geopandas as gpd
from shapely.geometry import box

# %%
import matplotlib.font_manager as fm

# 한국어 출력을 위한 폰트 설정
plt.rc('font', family='NanumGothic') 

# 마이너스 기호가 깨지는 것을 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv("data/구별_화재발생_현황_2021_2022.csv")

# %%
df.head()
# Out:
#    자치구   2021 소계 발생 (건)   2021 실화 발생 (건)  2021 방화 발생 (건)   2021 기타 발생 (건)  \
# 0  서울시             4951             4399              87              465
# 1  종로구              192              169               1               22
# 2   중구              171              136               3               32
# 3  용산구              176              160               1               15
# 4  성동구              191              163               2               26
#
#    2021 동수 소실 (동수)  2021 이재가구수 소실 (가구)   2021 면적 소실 (m²)   2021 소계 피해액 (천원)  \
# 0              468                 282             21723           18268346
# 1                -                   1               390             465499
# 2               47                   6              1350            2780374
# 3                6                  40               422             296793
# 4               14                   9               720             458412
#
#     2021 부동산 피해액 (천원)  ...   2022 기타 발생 (건)   2022 동수 소실 (동수)  \
# 0             6872172  ...              531               586
# 1              169588  ...               30                 2
# 2              686265  ...               26                27
# 3              123439  ...               25                 6
# 4              156128  ...               24                34
#
#    2022 이재가구수 소실 (가구)   2022 면적 소실 (m²)   2022 소계 피해액 (천원)  \
# 0                 234             34065           16592551
# 1                   1               501             272206
# 2                   5               956            2401154
# 3                  11               390             270752
# 4                   3              1997            1085583
#
#     2022 부동산 피해액 (천원)  2022 동산 피해액 (천원)   2022 계 인명피해 (명)  2022 사망 인명피해 (명)  \
# 0             6614971           9977580               362                37
# 1              151976            120230                12                 2
# 2              551299           1849855                24                 2
# 3               96719            174033                10                 2
# 4              313315            772268                11                 1
#
#    2022 부상 인명피해 (명)
# 0               325
# 1                10
# 2                22
# 3                 8
# 4                10
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['자치구', ' 2021 소계 발생 (건)', ' 2021 실화 발생 (건)', ' 2021 방화 발생 (건)',
#        ' 2021 기타 발생 (건)', ' 2021 동수 소실 (동수)', ' 2021 이재가구수 소실 (가구)',
#        ' 2021 면적 소실 (m²)', ' 2021 소계 피해액 (천원)', ' 2021 부동산 피해액 (천원)',
#        ' 2021 동산 피해액 (천원)', ' 2021 소계 인명피해 (명)', ' 2021 사망 인명피해 (명)',
#        ' 2021 부상 인명피해 (명)', ' 2022 소계 발생 (건)', ' 2022 실화 발생 (건)',
#        ' 2022 방화 발생 (건)', ' 2022 기타 발생 (건)', ' 2022 동수 소실 (동수)',
#        ' 2022 이재가구수 소실 (가구)', ' 2022 면적 소실 (m²)', ' 2022 소계 피해액 (천원)',
#        ' 2022 부동산 피해액 (천원)', ' 2022 동산 피해액 (천원)', ' 2022 계 인명피해 (명)',
#        ' 2022 사망 인명피해 (명)', ' 2022 부상 인명피해 (명)'],
#       dtype='object')
