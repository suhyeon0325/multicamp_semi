# %%
import folium
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import box
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
import matplotlib.font_manager as fm

# 한국어 출력을 위한 폰트 설정
plt.rc('font', family='NanumGothic') 

# 마이너스 기호가 깨지는 것을 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
gdf = gpd.read_file("data/시군구/sig.shp", encoding='euc-kr')
gdf
# Out:
#     SIG_CD    SIG_ENG_NM SIG_KOR_NM  \
# 0    11110     Jongno-gu        종로구
# 1    11140       Jung-gu         중구
# 2    11170    Yongsan-gu        용산구
# 3    11200  Seongdong-gu        성동구
# 4    11215   Gwangjin-gu        광진구
# ..     ...           ...        ...
# 247  52740    Jangsu-gun        장수군
# 248  52750     Imsil-gun        임실군
# 249  52770  Sunchang-gun        순창군
# 250  52790   Gochang-gun        고창군
# 251  52800      Buan-gun        부안군
#
#                                               geometry
# 0    POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1    POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2    POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3    POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4    POLYGON ((964825.058 1952633.250, 964875.565 1...
# ..                                                 ...
# 247  POLYGON ((1010833.697 1760276.768, 1010833.998...
# 248  POLYGON ((964208.319 1735959.093, 964238.552 1...
# ...

# %%
gdf = gdf.drop(columns='SIG_ENG_NM')
gdf
# Out:
#     SIG_CD SIG_KOR_NM                                           geometry
# 0    11110        종로구  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1    11140         중구  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2    11170        용산구  POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3    11200        성동구  POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4    11215        광진구  POLYGON ((964825.058 1952633.250, 964875.565 1...
# ..     ...        ...                                                ...
# 247  52740        장수군  POLYGON ((1010833.697 1760276.768, 1010833.998...
# 248  52750        임실군  POLYGON ((964208.319 1735959.093, 964238.552 1...
# 249  52770        순창군  POLYGON ((952623.909 1728974.778, 952672.751 1...
# 250  52790        고창군  MULTIPOLYGON (((902676.539 1717491.597, 902679...
# 251  52800        부안군  MULTIPOLYGON (((896426.602 1729753.332, 896412...
#
# [252 rows x 3 columns]

# %%
gdf = gdf[gdf['SIG_CD'].astype(str).str.startswith('11')]
gdf
# Out:
#    SIG_CD SIG_KOR_NM                                           geometry
# 0   11110        종로구  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1   11140         중구  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2   11170        용산구  POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3   11200        성동구  POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4   11215        광진구  POLYGON ((964825.058 1952633.250, 964875.565 1...
# 5   11230       동대문구  POLYGON ((962141.919 1956519.461, 962149.853 1...
# 6   11260        중랑구  POLYGON ((965698.531 1957987.355, 965772.290 1...
# 7   11290        성북구  POLYGON ((956787.318 1953542.506, 956761.258 1...
# 8   11305        강북구  POLYGON ((956316.789 1965175.345, 956401.551 1...
# 9   11320        도봉구  POLYGON ((957223.835 1961199.545, 957195.758 1...
# 10  11350        노원구  POLYGON ((965645.255 1960046.316, 965641.179 1...
# 11  11380        은평구  POLYGON ((951637.438 1961851.784, 951649.915 1...
# ...

# %%
gdf = gdf.drop(columns='SIG_CD')

# %%
gdf = gdf.rename(columns={'SIG_KOR_NM':'구'})

# %%
gdf = gdf.to_crs(epsg=4326)

# %%
gdf
# Out:
#        구                                           geometry
# 0    종로구  POLYGON ((127.00864 37.58047, 127.00871 37.580...
# 1     중구  POLYGON ((127.02314 37.57196, 127.02336 37.571...
# 2    용산구  POLYGON ((126.96918 37.55566, 126.96917 37.554...
# 3    성동구  POLYGON ((127.04341 37.57234, 127.04524 37.571...
# 4    광진구  POLYGON ((127.10166 37.57240, 127.10224 37.572...
# 5   동대문구  POLYGON ((127.07108 37.60732, 127.07117 37.606...
# 6    중랑구  POLYGON ((127.11131 37.62069, 127.11214 37.620...
# 7    성북구  POLYGON ((127.01059 37.58025, 127.01030 37.580...
# 8    강북구  POLYGON ((127.00457 37.68508, 127.00553 37.684...
# 9    도봉구  POLYGON ((127.01509 37.64929, 127.01477 37.649...
# 10   노원구  POLYGON ((127.11060 37.63925, 127.11056 37.639...
# 11   은평구  POLYGON ((126.95172 37.65489, 126.95186 37.654...
# 12  서대문구  POLYGON ((126.95268 37.60274, 126.95267 37.602...
# 13   마포구  POLYGON ((126.88888 37.58464, 126.88987 37.584...
# 14   양천구  POLYGON ((126.87405 37.54694, 126.87417 37.546...
# ...

# %%
gdf.to_file("data/구경계_geo.shp", encoding='utf-8')
